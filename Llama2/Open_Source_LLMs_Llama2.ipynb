# %% [markdown]
#  - Open LLMs: https://github.com/eugeneyan/open-llms
#  - chat with Llama: https://www.llama2.ai/
#  - Official Llama2 website: https://llama.meta.com/llama2
#  - Llama2 github: https://github.com/meta-llama/llama

# %%
# !nvidia-smi
# Out:
# Sat Mar 16 06:52:00 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install -q transformers einops accelerate langchain bitsandbytes

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: read).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
#import all important required libraries
from langchain.llms import HuggingFacePipeline

# %%
from transformers import AutoTokenizer

# %%
## Lets Create HuggingFace Pipeline

# %%
import transformers
import torch

# %%
model = "meta-llama/Llama-2-7b-chat-hf"

# %%
tokenizer = AutoTokenizer.from_pretrained(model)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
#keep default paramenters :
pipeline=transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
    max_length=1000,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id
    )
# Out:
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
llm = HuggingFacePipeline(pipeline=pipeline,model_kwargs={'temperature':0})

# %%
prompt="What would be a good name for a company that makes colorful socks"

# %%
print(llm(prompt))
# Out:
# ?
#
# Answer: Here are a few suggestions for a company that makes colorful socks:
#
# 1. SoleMates: This name plays on the idea of socks being a companion for your feet, and the word "mates" implies a fun and playful brand.
# 2. HueHues: This name incorporates the word "hue," which means a color or shade, and is a fun and catchy name for a sock company.
# 3. SockItToMe: This name is a play on the phrase "sock it to me," which means to impress or surprise someone, and is a fun and energetic name for a sock company.
# 4. Footloose & Fancy-Free: This name is a play on the phrase "footloose and fancy-free," which means feeling free and carefree, and is a fun and lighthearted name for a sock company.
# 5. SockSational: This name incorporates the word "sensational" and is a fun and catchy name for a sock company that offers colorful and stylish socks.
# 6. The Sock Society: This name implies a sense of exclusivity and sophistication, and is a fun and unique name for a sock company.
# 7. Socktastic: This name incorporates the word "fantastic" and is a fun and energetic name for a sock company that offers colorful and exciting socks.
# 8. The Sockery: This name is a play on the word "bakery" and is a fun and unique name for a sock company.
# 9. SockStories: This name implies that each sock has its own unique story and is a fun and creative name for a sock company.
# 10. The Sock Syndicate: This name implies a sense of organization and is a fun and unique name for a sock company.
#
# I hope these suggestions help inspire you to come up with the perfect name for your company!

# %%
prompt="I want to open a restaurant for  indian food. Suggest me a fence name for this"

# %%
print(llm(prompt))
# Out:
#  restaurant.
# I am glad you are interested in opening a restaurant for Indian food! Here are some suggestions for a unique and catchy name for your restaurant:
# 1. Tandoor Nights: Tandoor is a traditional Indian clay oven used for cooking, and "Nights" suggests a cozy and intimate atmosphere.
# 2. Spice Route: This name plays on the idea of the ancient spice trade routes that connected India to other parts of the world, and suggests a restaurant that offers a diverse and flavorful menu.
# 3. Mumbai Morsels: Mumbai is the financial capital of India, and "Morsels" suggests small, bite-sized portions of delicious food.
# 4. Naan Stop: Naan is a popular Indian flatbread, and "Stop" suggests a place where you can satisfy your cravings for Indian cuisine.
# 5. Biryani Bazaar: Biryani is a popular Indian rice dish, and "Bazaar" suggests a lively and bustling marketplace where you can find all sorts of delicious Indian food.
# 6. Tikka Temptations: Tikka is a popular Indian cooking technique that involves marinating meat in spices and yogurt, and "Temptations" suggests a restaurant that will tempt your taste buds with its delicious dishes.
# 7. Curry Cove: Curry is a popular Indian sauce made with a variety of spices, and "Cove" suggests a cozy and intimate atmosphere.
# 8. Masala Mansion: Masala is a blend of spices used in Indian cooking, and "Mansion" suggests a grand and luxurious restaurant.
# 9. Korma Kingdom: Korma is a popular Indian dish made with yogurt and spices, and "Kingdom" suggests a restaurant that rules the hearts of its customers with its delicious food.
# 10. Dosa Den: Dosa is a popular Indian fermented crepe, and "Den" suggests a cozy and welcoming place where you can enjoy a delicious meal.
#
# I hope these suggestions help you find the perfect name for your Indian restaurant!
